# %%
# Get the data from Movielens website
from urllib.request import urlretrieve
import zipfile
import pandas as pd

urlretrieve("http://files.grouplens.org/datasets/movielens/ml-100k.zip", "movielens.zip")
zip_ref = zipfile.ZipFile('movielens.zip', "r")
zip_ref.extractall()
print("Done. Dataset contains:")
print(zip_ref.read('ml-100k/u.info'))

#Process the dataset for movies, users,ratings and genre
# Load each data set (users, movies, and ratings).
users_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv(
    'ml-100k/u.user', sep='|', names=users_cols, encoding='latin-1')

ratings_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv(
    'ml-100k/u.data', sep='\t', names=ratings_cols, encoding='latin-1')

# The movies file contains a binary feature for each genre.
genre_cols = [
    "genre_unknown", "Action", "Adventure", "Animation", "Children", "Comedy",
    "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror",
    "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western",
]
movies_cols = [
    'movie_id', 'title', 'release_date', "video_release_date", "imdb_url"
] + genre_cols
movies = pd.read_csv(
    'ml-100k/u.item', sep='|', names=movies_cols, encoding='latin-1')

# Since the ids start at 1, we shift them to start at 0.
users["user_id"] = users["user_id"].apply(lambda x: str(x-1))
movies["movie_id"] = movies["movie_id"].apply(lambda x: str(x-1))
movies["year"] = movies['release_date'].apply(lambda x: str(x).split('-')[-1])
ratings["movie_id"] = ratings["movie_id"].apply(lambda x: str(x-1))
ratings["user_id"] = ratings["user_id"].apply(lambda x: str(x-1))
ratings["rating"] = ratings["rating"].apply(lambda x: float(x))
# Out:
# Done. Dataset contains:
# b'943 users\n1682 items\n100000 ratings\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Get all the genres for a movie
import numpy as np
genre_occurences = movies[genre_cols].sum().to_dict()

genres_encoded = {x: i for i, x in enumerate(genre_cols)}

def get_genres(movies, genres):
  def get_all_genres(gs):
    active = [str(genres_encoded[genre]) for genre, g in zip(genres, gs) if g==1]
    if len(active) == 0:
      return '0'
    return ','.join((active))
  movies['all_genres'] = [
      get_all_genres(gs) for gs in zip(*[movies[genre] for genre in genres])]

get_genres(movies, genre_cols)

# %%
movies.head(3)
# Out:
#   movie_id              title release_date  ...  Western  year  all_genres
# 0        0   Toy Story (1995)  01-Jan-1995  ...        0  1995       3,4,5
# 1        1   GoldenEye (1995)  01-Jan-1995  ...        0  1995      1,2,16
# 2        2  Four Rooms (1995)  01-Jan-1995  ...        0  1995          16
#
# [3 rows x 26 columns]

# %%
rating_details_sample = ratings.merge(movies, on='movie_id').merge(users, on='user_id')

# %%
rating_details_sample.shape
# Out:
# (100000, 33)

# %%
rating_details_sample.head(10)
# Out:
#   user_id movie_id  rating  unix_timestamp  ... age sex  occupation zip_code
# 0     195      241     3.0       881250949  ...  49   M      writer    55105
# 1     195      256     2.0       881251577  ...  49   M      writer    55105
# 2     195      110     4.0       881251793  ...  49   M      writer    55105
# 3     195       24     4.0       881251955  ...  49   M      writer    55105
# 4     195      381     4.0       881251843  ...  49   M      writer    55105
# 5     195      201     3.0       881251728  ...  49   M      writer    55105
# 6     195      152     5.0       881251820  ...  49   M      writer    55105
# 7     195      285     5.0       881250949  ...  49   M      writer    55105
# 8     195       65     3.0       881251911  ...  49   M      writer    55105
# 9     195      844     4.0       881251954  ...  49   M      writer    55105
#
# [10 rows x 33 columns]

# %%
rating_details_sample['user_id']=rating_details_sample['user_id'].astype(int)
rating_details_sample['movie_id']=rating_details_sample['movie_id'].astype(int)

# %%
rating_details_sample=rating_details_sample.set_index(['user_id','unix_timestamp']).sort_index()

# %%
rating_details_sample =rating_details_sample.reset_index()

# %%
# Get the like and dislike movie list
import numpy as np
rating_details_sample['movie_type'] = np.where(rating_details_sample['rating'] >=3, 'like','dislike')
rating_details_sample['movie_name'] = rating_details_sample['title'].str[:-6]

# %%
rating_details_sample.head(10)
# Out:
#    user_id  unix_timestamp  ...  movie_type                                movie_name
# 0        0       874965478  ...        like                 Empire Strikes Back, The
# 1        0       874965478  ...        like          Monty Python and the Holy Grail
# 2        0       874965518  ...        like                         Jean de Florette
# 3        0       874965556  ...        like                           Reservoir Dogs
# 4        0       874965677  ...        like                       Dead Poets Society
# 5        0       874965677  ...        like  Manon of the Spring (Manon des sources)
# 6        0       874965678  ...        like                  Godfather: Part II, The
# 7        0       874965706  ...        like                              Postino, Il
# 8        0       874965706  ...        like                           Godfather, The
# 9        0       874965706  ...        like                       Fifth Element, The
#
# [10 rows x 35 columns]

# %%
user_ids = rating_details_sample["user_id"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}

movie_ids = rating_details_sample["movie_id"].unique().tolist()
movie2movie_encoded = {x: i for i, x in enumerate(movie_ids)}
movie_encoded2movie = {i: x for i, x in enumerate(movie_ids)}

title_ids = rating_details_sample["movie_name"].unique().tolist()
title2title_encoded = {x: i for i, x in enumerate(title_ids)}
title_encoded2title = {i: x for i, x in enumerate(title_ids)}


rating_details_sample["user"] = rating_details_sample["user_id"].map(user2user_encoded)
rating_details_sample["movie"] = rating_details_sample["movie_id"].map(movie2movie_encoded)
rating_details_sample["title_d"] = rating_details_sample["movie_name"].map(title2title_encoded)

# %%
sample_data=rating_details_sample[['user','occupation','sex']]

# %%
sample_data=sample_data.reset_index()

# %%
rating_details_sample["movie"].max()
# Out:
# 1681

# %%
movie_list = rating_details_sample.groupby(['user','movie_type'])['movie'].apply(list).reset_index()
title_list = rating_details_sample.groupby(['user'])['title_d'].apply(list).reset_index()
genre_list = rating_details_sample.groupby(['user'])['all_genres'].unique().apply(list).reset_index()

# %%
# Get the unique set of genre for all the users
genre_list['all_genres']=genre_list['all_genres'].apply(lambda x: list(set(','.join(x))) ) 
genre_list['all_genres']=genre_list['all_genres'].apply(lambda x:[ x for x in x if x.isdigit() ])

# %%
user_video_list = movie_list.pivot(index='user', columns='movie_type', values='movie').reset_index()

# %%
user_video_list.fillna(rating_details_sample["movie"].max()+1, inplace=True)

# %%
sample_data = sample_data.drop('index',axis=1)

# %%
sample_data =sample_data.drop_duplicates()

# %%
user_final_list =pd.merge(user_video_list,title_list, how= 'left')
user_title_list1 = pd.merge(user_final_list,genre_list, how='left')
user_title_list = pd.merge(user_title_list1,sample_data, how='left')

# %%
user_title_list1.head(3)
# Out:
#    user  ...                      all_genres
# 0     0  ...  [7, 2, 1, 0, 5, 6, 8, 4, 3, 9]
# 1     1  ...  [7, 2, 1, 0, 5, 6, 8, 4, 3, 9]
# 2     2  ...     [7, 2, 1, 0, 6, 5, 8, 4, 3]
#
# [3 rows x 5 columns]

# %%
user_title_list['like'] =user_title_list['like'].apply(lambda x: x if type(x) is list else [x])
user_title_list['dislike'] =user_title_list['dislike'].apply(lambda x: x if type(x) is list else [x])

# %%
user_title_list['predict_labels'] = user_title_list['like'].apply(lambda x: (x[-1]))

# %%
user_title_list['like']=user_title_list['like'].apply(lambda x: (x[:-1]))

# %%
pd.DataFrame(user_title_list[['user','dislike','like','title_d','all_genres','predict_labels']]).head(4)
# Out:
#    user  ... predict_labels
# 0     0  ...            269
# 1     1  ...            315
# 2     2  ...            354
# 3     3  ...             55
#
# [4 rows x 6 columns]

# %%
user_title_list_e=user_title_list[(user_title_list.user >= 1)&
                                  (user_title_list.user <= 500)]

# %%
user_title_list.shape
# Out:
# (943, 8)

# %%
EMBEDDING_DIMS = 16
DENSE_UNITS = 64
DROPOUT_PCT = 0.0
ALPHA = 0.0
NUM_CLASSES=rating_details_sample["movie"].max()+2

LEARNING_RATE = 0.003

# %%
import tensorflow as tf
class MaskedEmbeddingsAggregatorLayer(tf.keras.layers.Layer):
    def __init__(self, agg_mode='sum', **kwargs):
        super(MaskedEmbeddingsAggregatorLayer, self).__init__(**kwargs)

        if agg_mode not in ['sum', 'mean']:
            raise NotImplementedError('mode {} not implemented!'.format(agg_mode))
        self.agg_mode = agg_mode
    
    @tf.function
    def call(self, inputs, mask=None):
        masked_embeddings = tf.ragged.boolean_mask(inputs, mask)
        if self.agg_mode == 'sum':
            aggregated =  tf.reduce_sum(masked_embeddings, axis=1)
        elif self.agg_mode == 'mean':
            aggregated = tf.reduce_mean(masked_embeddings, axis=1)
        
        return aggregated
    
    def get_config(self):
        # this is used when loading a saved model that uses a custom layer
        return {'agg_mode': self.agg_mode}

# %%
class L2NormLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(L2NormLayer, self).__init__(**kwargs)
    
    @tf.function
    def call(self, inputs, mask=None):
        if mask is not None:
            inputs = tf.ragged.boolean_mask(inputs, mask).to_tensor()
        return tf.math.l2_normalize(inputs, axis=-1)

    def compute_mask(self, inputs, mask):
        return mask

# %%
#---inputs
import tensorflow as tf
import datetime
import os
input_title = tf.keras.Input(shape=(None, ), name='movie_name')
inp_video_liked = tf.keras.layers.Input(shape=(None,), name='like')
inp_video_disliked = tf.keras.layers.Input(shape=(None,), name='dislike')
input_genre = tf.keras.Input(shape=(None, ), name='genre')


#--- layers
features_embedding_layer = tf.keras.layers.Embedding(input_dim=NUM_CLASSES, output_dim=EMBEDDING_DIMS, 
                                            mask_zero=True, trainable=True, name='features_embeddings')
labels_embedding_layer = tf.keras.layers.Embedding(input_dim=NUM_CLASSES, output_dim=EMBEDDING_DIMS, 
                                            mask_zero=True, trainable=True, name='labels_embeddings')

avg_embeddings = MaskedEmbeddingsAggregatorLayer(agg_mode='mean', name='aggregate_embeddings')

dense_1 = tf.keras.layers.Dense(units=DENSE_UNITS, name='dense_1')
dense_2 = tf.keras.layers.Dense(units=DENSE_UNITS, name='dense_2')
dense_3 = tf.keras.layers.Dense(units=DENSE_UNITS, name='dense_3')
l2_norm_1 = L2NormLayer(name='l2_norm_1')

dense_output = tf.keras.layers.Dense(NUM_CLASSES, activation=tf.nn.softmax, name='dense_output')

#--- features
features_embeddings = features_embedding_layer(input_title)
l2_norm_features = l2_norm_1(features_embeddings)
avg_features = avg_embeddings(l2_norm_features)

labels_liked_embeddings = labels_embedding_layer(inp_video_liked)
l2_norm_liked = l2_norm_1(labels_liked_embeddings)
avg_liked = avg_embeddings(l2_norm_liked)

labels_disliked_embeddings = labels_embedding_layer(inp_video_disliked)
l2_norm_disliked = l2_norm_1(labels_disliked_embeddings)
avg_disliked = avg_embeddings(l2_norm_disliked)

labels_genre_embeddings = labels_embedding_layer(input_genre)
l2_norm_genre = l2_norm_1(labels_genre_embeddings)
avg_genre = avg_embeddings(l2_norm_genre)



concat_inputs = tf.keras.layers.Concatenate(axis=1)([avg_features,
                                                     avg_liked,
                                                     avg_disliked,
                                                     avg_genre
                                                     ])
# Dense Layers

dense_1_features = dense_1(concat_inputs)
dense_1_relu = tf.keras.layers.ReLU(name='dense_1_relu')(dense_1_features)
dense_1_batch_norm = tf.keras.layers.BatchNormalization(name='dense_1_batch_norm')(dense_1_relu)

dense_2_features = dense_2(dense_1_relu)
dense_2_relu = tf.keras.layers.ReLU(name='dense_2_relu')(dense_2_features)
#dense_2_batch_norm = tf.keras.layers.BatchNormalization(name='dense_2_batch_norm')(dense_2_relu)

dense_3_features = dense_3(dense_2_relu)
dense_3_relu = tf.keras.layers.ReLU(name='dense_3_relu')(dense_3_features)
dense_3_batch_norm = tf.keras.layers.BatchNormalization(name='dense_3_batch_norm')(dense_3_relu)
outputs = dense_output(dense_3_batch_norm)

#Optimizer
optimiser = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)

#--- prep model
model = tf.keras.models.Model(
    inputs=[input_title, inp_video_liked, 
            inp_video_disliked
            ,input_genre
            ],
    outputs=[outputs]
)
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
model.compile(optimizer=optimiser, loss='sparse_categorical_crossentropy')

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True,dpi=96)

# %%
model.fit([tf.keras.preprocessing.sequence.pad_sequences(user_title_list_e['title_d']),
           tf.keras.preprocessing.sequence.pad_sequences(user_title_list_e['like']),
           tf.keras.preprocessing.sequence.pad_sequences(user_title_list_e['dislike'])
           ,
            tf.keras.preprocessing.sequence.pad_sequences(user_title_list_e['all_genres'])
           ],user_title_list_e['predict_labels'].values,callbacks=[tensorboard_callback],
           steps_per_epoch=1, epochs=1000,verbose=1)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 5s 5s/step - loss: 7.4236
# Epoch 2/1000
# 1/1 [==============================] - 1s 533ms/step - loss: 7.4255
# Epoch 3/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 7.4191
# Epoch 4/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 7.4160
# Epoch 5/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 7.4081
# Epoch 6/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 7.3980
# Epoch 7/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 7.3933
# Epoch 8/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 7.3791
# Epoch 9/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 7.3588
# Epoch 10/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 7.3564
# Epoch 11/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 7.3478
# Epoch 12/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 7.3381
# Epoch 13/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 7.3136
# Epoch 14/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 7.2916
# Epoch 15/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 7.2805
# Epoch 16/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 7.2598
# Epoch 17/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 7.2358
# Epoch 18/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 7.2225
# Epoch 19/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 7.1850
# Epoch 20/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 7.1638
# Epoch 21/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 7.1377
# Epoch 22/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 7.1072
# Epoch 23/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 7.0724
# Epoch 24/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 7.0414
# Epoch 25/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 7.0127
# Epoch 26/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.9688
# Epoch 27/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.9287
# Epoch 28/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 6.8888
# Epoch 29/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 6.8542
# Epoch 30/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 6.8077
# Epoch 31/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 6.7735
# Epoch 32/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.7226
# Epoch 33/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.6736
# Epoch 34/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 6.6291
# Epoch 35/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.5851
# Epoch 36/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.5357
# Epoch 37/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.4972
# Epoch 38/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 6.4390
# Epoch 39/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.3973
# Epoch 40/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 6.3516
# Epoch 41/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 6.3126
# Epoch 42/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.2724
# Epoch 43/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.2245
# Epoch 44/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.1863
# Epoch 45/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 6.1571
# Epoch 46/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.1241
# Epoch 47/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.0904
# Epoch 48/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 6.0554
# Epoch 49/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.0254
# Epoch 50/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 6.0013
# Epoch 51/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.9702
# Epoch 52/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.9515
# Epoch 53/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.9231
# Epoch 54/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.9077
# Epoch 55/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.8880
# Epoch 56/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.8706
# Epoch 57/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.8510
# Epoch 58/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.8256
# Epoch 59/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 5.8078
# Epoch 60/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.7851
# Epoch 61/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.7833
# Epoch 62/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 5.7673
# Epoch 63/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.7497
# Epoch 64/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.7331
# Epoch 65/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.7169
# Epoch 66/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.7206
# Epoch 67/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.7124
# Epoch 68/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.6903
# Epoch 69/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.6977
# Epoch 70/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.6626
# Epoch 71/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.6451
# Epoch 72/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.6488
# Epoch 73/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.6445
# Epoch 74/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.6008
# Epoch 75/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.6363
# Epoch 76/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.5986
# Epoch 77/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.5951
# Epoch 78/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.6106
# Epoch 79/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.5805
# Epoch 80/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 5.5614
# Epoch 81/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.5971
# Epoch 82/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.5576
# Epoch 83/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.5331
# Epoch 84/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.5233
# Epoch 85/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.5733
# Epoch 86/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.5192
# Epoch 87/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.5519
# Epoch 88/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.5114
# Epoch 89/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.5309
# Epoch 90/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.5443
# Epoch 91/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4812
# Epoch 92/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.5051
# Epoch 93/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 5.4941
# Epoch 94/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.4518
# Epoch 95/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4674
# Epoch 96/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.4861
# Epoch 97/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.4876
# Epoch 98/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.5142
# Epoch 99/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.4676
# Epoch 100/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.5054
# Epoch 101/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4195
# Epoch 102/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.4341
# Epoch 103/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.4527
# Epoch 104/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.4436
# Epoch 105/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.4854
# Epoch 106/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.4331
# Epoch 107/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4195
# Epoch 108/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4219
# Epoch 109/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.4146
# Epoch 110/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.3897
# Epoch 111/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.4241
# Epoch 112/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.4083
# Epoch 113/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.4049
# Epoch 114/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.4064
# Epoch 115/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.3874
# Epoch 116/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.3893
# Epoch 117/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.3691
# Epoch 118/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.3702
# Epoch 119/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 5.3546
# Epoch 120/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 5.4055
# Epoch 121/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.4267
# Epoch 122/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.3039
# Epoch 123/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.3294
# Epoch 124/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.3751
# Epoch 125/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.3217
# Epoch 126/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2994
# Epoch 127/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.3142
# Epoch 128/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.3489
# Epoch 129/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2865
# Epoch 130/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.3403
# Epoch 131/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 5.3413
# Epoch 132/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.3019
# Epoch 133/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.3408
# Epoch 134/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.3481
# Epoch 135/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2701
# Epoch 136/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.3311
# Epoch 137/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2580
# Epoch 138/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.3005
# Epoch 139/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2952
# Epoch 140/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.2886
# Epoch 141/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.3128
# Epoch 142/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.2633
# Epoch 143/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.3375
# Epoch 144/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.2825
# Epoch 145/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.3005
# Epoch 146/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2854
# Epoch 147/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.2955
# Epoch 148/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2512
# Epoch 149/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.2842
# Epoch 150/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2576
# Epoch 151/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2181
# Epoch 152/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.2554
# Epoch 153/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.2875
# Epoch 154/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.3031
# Epoch 155/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.2594
# Epoch 156/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2249
# Epoch 157/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.2401
# Epoch 158/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2115
# Epoch 159/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2562
# Epoch 160/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2359
# Epoch 161/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2962
# Epoch 162/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.1982
# Epoch 163/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2126
# Epoch 164/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1852
# Epoch 165/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.2228
# Epoch 166/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1948
# Epoch 167/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.2325
# Epoch 168/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2332
# Epoch 169/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.1633
# Epoch 170/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.2231
# Epoch 171/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 5.1661
# Epoch 172/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2427
# Epoch 173/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1658
# Epoch 174/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1978
# Epoch 175/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1979
# Epoch 176/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.2431
# Epoch 177/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.2376
# Epoch 178/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2135
# Epoch 179/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.2090
# Epoch 180/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.2639
# Epoch 181/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 5.1979
# Epoch 182/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.2337
# Epoch 183/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1864
# Epoch 184/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1302
# Epoch 185/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.2322
# Epoch 186/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.2279
# Epoch 187/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.2369
# Epoch 188/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.2367
# Epoch 189/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1611
# Epoch 190/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1744
# Epoch 191/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.2052
# Epoch 192/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1672
# Epoch 193/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.2039
# Epoch 194/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 5.1962
# Epoch 195/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.1880
# Epoch 196/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1784
# Epoch 197/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.1756
# Epoch 198/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1928
# Epoch 199/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1008
# Epoch 200/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1719
# Epoch 201/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1972
# Epoch 202/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 5.1580
# Epoch 203/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1639
# Epoch 204/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1261
# Epoch 205/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1652
# Epoch 206/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.2665
# Epoch 207/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1406
# Epoch 208/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.1771
# Epoch 209/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1324
# Epoch 210/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.1722
# Epoch 211/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.1308
# Epoch 212/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1795
# Epoch 213/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.2075
# Epoch 214/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1303
# Epoch 215/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1401
# Epoch 216/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.1708
# Epoch 217/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1262
# Epoch 218/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.1237
# Epoch 219/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1351
# Epoch 220/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.1132
# Epoch 221/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.1201
# Epoch 222/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.1733
# Epoch 223/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1016
# Epoch 224/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1313
# Epoch 225/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1378
# Epoch 226/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0668
# Epoch 227/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0980
# Epoch 228/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0915
# Epoch 229/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.1503
# Epoch 230/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1451
# Epoch 231/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.1420
# Epoch 232/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1054
# Epoch 233/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1328
# Epoch 234/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.1221
# Epoch 235/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.1533
# Epoch 236/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.1207
# Epoch 237/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0921
# Epoch 238/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0703
# Epoch 239/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0807
# Epoch 240/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.1183
# Epoch 241/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.1128
# Epoch 242/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.1258
# Epoch 243/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1078
# Epoch 244/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.1018
# Epoch 245/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0235
# Epoch 246/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.0980
# Epoch 247/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.0982
# Epoch 248/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 5.0702
# Epoch 249/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0644
# Epoch 250/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0651
# Epoch 251/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0703
# Epoch 252/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0668
# Epoch 253/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.0759
# Epoch 254/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.0440
# Epoch 255/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0554
# Epoch 256/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.0244
# Epoch 257/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0982
# Epoch 258/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0582
# Epoch 259/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0795
# Epoch 260/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0376
# Epoch 261/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0826
# Epoch 262/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.0874
# Epoch 263/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.0663
# Epoch 264/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.0258
# Epoch 265/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9933
# Epoch 266/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0724
# Epoch 267/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0564
# Epoch 268/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9922
# Epoch 269/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0264
# Epoch 270/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0763
# Epoch 271/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0521
# Epoch 272/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.0705
# Epoch 273/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.0423
# Epoch 274/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0706
# Epoch 275/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 5.0259
# Epoch 276/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0460
# Epoch 277/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0450
# Epoch 278/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9842
# Epoch 279/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 5.0364
# Epoch 280/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.0724
# Epoch 281/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.0251
# Epoch 282/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0384
# Epoch 283/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0518
# Epoch 284/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0230
# Epoch 285/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.0439
# Epoch 286/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0291
# Epoch 287/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.0400
# Epoch 288/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9946
# Epoch 289/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9943
# Epoch 290/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9895
# Epoch 291/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0393
# Epoch 292/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9759
# Epoch 293/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.0473
# Epoch 294/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 4.9958
# Epoch 295/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 5.0144
# Epoch 296/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0137
# Epoch 297/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 5.0202
# Epoch 298/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 5.0120
# Epoch 299/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 5.0059
# Epoch 300/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.9649
# Epoch 301/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 5.0148
# Epoch 302/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 5.0336
# Epoch 303/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 4.9890
# Epoch 304/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.0217
# Epoch 305/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.9671
# Epoch 306/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.0184
# Epoch 307/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 4.9841
# Epoch 308/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 5.0334
# Epoch 309/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9928
# Epoch 310/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.9669
# Epoch 311/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9642
# Epoch 312/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9887
# Epoch 313/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9420
# Epoch 314/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0218
# Epoch 315/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0226
# Epoch 316/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 5.0007
# Epoch 317/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9769
# Epoch 318/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9728
# Epoch 319/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9720
# Epoch 320/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0002
# Epoch 321/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9476
# Epoch 322/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0389
# Epoch 323/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9769
# Epoch 324/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0228
# Epoch 325/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9727
# Epoch 326/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9420
# Epoch 327/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 5.0196
# Epoch 328/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9491
# Epoch 329/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9889
# Epoch 330/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 5.0270
# Epoch 331/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8903
# Epoch 332/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9714
# Epoch 333/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9793
# Epoch 334/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.9719
# Epoch 335/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9016
# Epoch 336/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9349
# Epoch 337/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9539
# Epoch 338/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9935
# Epoch 339/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9763
# Epoch 340/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9888
# Epoch 341/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.9298
# Epoch 342/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0005
# Epoch 343/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9464
# Epoch 344/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9695
# Epoch 345/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9223
# Epoch 346/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9735
# Epoch 347/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9835
# Epoch 348/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9637
# Epoch 349/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9277
# Epoch 350/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9202
# Epoch 351/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8882
# Epoch 352/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 4.9459
# Epoch 353/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0079
# Epoch 354/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9723
# Epoch 355/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9477
# Epoch 356/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 4.9392
# Epoch 357/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 5.0061
# Epoch 358/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9523
# Epoch 359/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9884
# Epoch 360/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9470
# Epoch 361/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9088
# Epoch 362/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.9287
# Epoch 363/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9573
# Epoch 364/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9172
# Epoch 365/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9241
# Epoch 366/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.9191
# Epoch 367/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8931
# Epoch 368/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9548
# Epoch 369/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9761
# Epoch 370/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 4.9188
# Epoch 371/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9210
# Epoch 372/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9311
# Epoch 373/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0053
# Epoch 374/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.9202
# Epoch 375/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8696
# Epoch 376/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9336
# Epoch 377/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9171
# Epoch 378/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9262
# Epoch 379/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9741
# Epoch 380/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8609
# Epoch 381/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8862
# Epoch 382/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9536
# Epoch 383/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9341
# Epoch 384/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.8647
# Epoch 385/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9960
# Epoch 386/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9339
# Epoch 387/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 4.8740
# Epoch 388/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9085
# Epoch 389/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8823
# Epoch 390/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8732
# Epoch 391/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8999
# Epoch 392/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8961
# Epoch 393/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9205
# Epoch 394/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8892
# Epoch 395/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8915
# Epoch 396/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8866
# Epoch 397/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.9137
# Epoch 398/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8983
# Epoch 399/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9258
# Epoch 400/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8795
# Epoch 401/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 4.9388
# Epoch 402/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9112
# Epoch 403/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.9045
# Epoch 404/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9028
# Epoch 405/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9627
# Epoch 406/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9103
# Epoch 407/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8957
# Epoch 408/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9054
# Epoch 409/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9296
# Epoch 410/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.8741
# Epoch 411/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8769
# Epoch 412/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9050
# Epoch 413/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8522
# Epoch 414/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8604
# Epoch 415/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9159
# Epoch 416/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9469
# Epoch 417/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9351
# Epoch 418/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8877
# Epoch 419/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8693
# Epoch 420/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8597
# Epoch 421/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9039
# Epoch 422/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8317
# Epoch 423/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8454
# Epoch 424/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8470
# Epoch 425/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8758
# Epoch 426/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8276
# Epoch 427/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.9029
# Epoch 428/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8787
# Epoch 429/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8916
# Epoch 430/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8914
# Epoch 431/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8923
# Epoch 432/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8423
# Epoch 433/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8609
# Epoch 434/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8383
# Epoch 435/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.9197
# Epoch 436/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 4.8990
# Epoch 437/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.9127
# Epoch 438/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8783
# Epoch 439/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.8480
# Epoch 440/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8530
# Epoch 441/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.8334
# Epoch 442/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8493
# Epoch 443/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8366
# Epoch 444/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8827
# Epoch 445/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.8535
# Epoch 446/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8700
# Epoch 447/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9328
# Epoch 448/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8572
# Epoch 449/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.8758
# Epoch 450/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8492
# Epoch 451/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.8783
# Epoch 452/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8431
# Epoch 453/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8356
# Epoch 454/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.8953
# Epoch 455/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8683
# Epoch 456/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9004
# Epoch 457/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.9393
# Epoch 458/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.9096
# Epoch 459/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.9007
# Epoch 460/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9092
# Epoch 461/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9333
# Epoch 462/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8488
# Epoch 463/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.9146
# Epoch 464/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8966
# Epoch 465/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9381
# Epoch 466/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 4.8616
# Epoch 467/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8983
# Epoch 468/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8263
# Epoch 469/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.9212
# Epoch 470/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8736
# Epoch 471/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8648
# Epoch 472/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8812
# Epoch 473/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8920
# Epoch 474/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8614
# Epoch 475/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.8571
# Epoch 476/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8543
# Epoch 477/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 4.8929
# Epoch 478/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8470
# Epoch 479/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.9130
# Epoch 480/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8875
# Epoch 481/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8424
# Epoch 482/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8568
# Epoch 483/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8234
# Epoch 484/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.9495
# Epoch 485/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8427
# Epoch 486/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8616
# Epoch 487/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8512
# Epoch 488/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8789
# Epoch 489/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8804
# Epoch 490/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.9010
# Epoch 491/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8893
# Epoch 492/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8263
# Epoch 493/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8409
# Epoch 494/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8767
# Epoch 495/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8898
# Epoch 496/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.8305
# Epoch 497/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8612
# Epoch 498/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8033
# Epoch 499/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.8163
# Epoch 500/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8160
# Epoch 501/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.8262
# Epoch 502/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8826
# Epoch 503/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8813
# Epoch 504/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8624
# Epoch 505/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8406
# Epoch 506/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8408
# Epoch 507/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 4.8139
# Epoch 508/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7835
# Epoch 509/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8771
# Epoch 510/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7821
# Epoch 511/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8740
# Epoch 512/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7961
# Epoch 513/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8176
# Epoch 514/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8722
# Epoch 515/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8426
# Epoch 516/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.8799
# Epoch 517/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7954
# Epoch 518/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8294
# Epoch 519/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8404
# Epoch 520/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8597
# Epoch 521/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.7930
# Epoch 522/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8052
# Epoch 523/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8464
# Epoch 524/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8092
# Epoch 525/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8219
# Epoch 526/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.8235
# Epoch 527/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.8705
# Epoch 528/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8525
# Epoch 529/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8615
# Epoch 530/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8503
# Epoch 531/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7687
# Epoch 532/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7972
# Epoch 533/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7993
# Epoch 534/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.9122
# Epoch 535/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7681
# Epoch 536/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8324
# Epoch 537/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8218
# Epoch 538/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7659
# Epoch 539/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7807
# Epoch 540/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8163
# Epoch 541/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8623
# Epoch 542/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8331
# Epoch 543/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8034
# Epoch 544/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7822
# Epoch 545/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.8512
# Epoch 546/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.8171
# Epoch 547/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.8116
# Epoch 548/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7753
# Epoch 549/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7955
# Epoch 550/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8824
# Epoch 551/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.8330
# Epoch 552/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8531
# Epoch 553/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7762
# Epoch 554/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8233
# Epoch 555/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8243
# Epoch 556/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.8797
# Epoch 557/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.8439
# Epoch 558/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.7011
# Epoch 559/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8196
# Epoch 560/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8036
# Epoch 561/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7883
# Epoch 562/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7360
# Epoch 563/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7732
# Epoch 564/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.8303
# Epoch 565/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7857
# Epoch 566/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7759
# Epoch 567/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7958
# Epoch 568/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7931
# Epoch 569/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7814
# Epoch 570/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.8310
# Epoch 571/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.8515
# Epoch 572/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.7827
# Epoch 573/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.7455
# Epoch 574/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7945
# Epoch 575/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7948
# Epoch 576/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7804
# Epoch 577/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8778
# Epoch 578/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7553
# Epoch 579/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7929
# Epoch 580/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7357
# Epoch 581/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8222
# Epoch 582/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.8231
# Epoch 583/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7979
# Epoch 584/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7544
# Epoch 585/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7509
# Epoch 586/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7677
# Epoch 587/1000
# ...
# Epoch 806/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6286
# Epoch 807/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.6950
# Epoch 808/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7156
# Epoch 809/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7187
# Epoch 810/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7374
# Epoch 811/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7121
# Epoch 812/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6803
# Epoch 813/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.6669
# Epoch 814/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7143
# Epoch 815/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7280
# Epoch 816/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7229
# Epoch 817/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7082
# Epoch 818/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.7140
# Epoch 819/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7256
# Epoch 820/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6900
# Epoch 821/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7321
# Epoch 822/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6877
# Epoch 823/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6716
# Epoch 824/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6857
# Epoch 825/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7848
# Epoch 826/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6551
# Epoch 827/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 4.6875
# Epoch 828/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7485
# Epoch 829/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6673
# Epoch 830/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.7039
# Epoch 831/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7032
# Epoch 832/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7203
# Epoch 833/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7253
# Epoch 834/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7311
# Epoch 835/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.7269
# Epoch 836/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7178
# Epoch 837/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6742
# Epoch 838/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6404
# Epoch 839/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.6956
# Epoch 840/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7191
# Epoch 841/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7550
# Epoch 842/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7502
# Epoch 843/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6998
# Epoch 844/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.6580
# Epoch 845/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.7310
# Epoch 846/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6707
# Epoch 847/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7351
# Epoch 848/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6221
# Epoch 849/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.6788
# Epoch 850/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6614
# Epoch 851/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7274
# Epoch 852/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6899
# Epoch 853/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7339
# Epoch 854/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6865
# Epoch 855/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7064
# Epoch 856/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 4.6516
# Epoch 857/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6995
# Epoch 858/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 4.6564
# Epoch 859/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.5988
# Epoch 860/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7007
# Epoch 861/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.7107
# Epoch 862/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7324
# Epoch 863/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6289
# Epoch 864/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6763
# Epoch 865/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6528
# Epoch 866/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6881
# Epoch 867/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7423
# Epoch 868/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7326
# Epoch 869/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6868
# Epoch 870/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.7096
# Epoch 871/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6567
# Epoch 872/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.6610
# Epoch 873/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.6442
# Epoch 874/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7360
# Epoch 875/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7707
# Epoch 876/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 4.6921
# Epoch 877/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6244
# Epoch 878/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.6437
# Epoch 879/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.5865
# Epoch 880/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6631
# Epoch 881/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7356
# Epoch 882/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6800
# Epoch 883/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6931
# Epoch 884/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6483
# Epoch 885/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 4.7132
# Epoch 886/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6861
# Epoch 887/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7031
# Epoch 888/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6713
# Epoch 889/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6498
# Epoch 890/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7050
# Epoch 891/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.6678
# Epoch 892/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6787
# Epoch 893/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6628
# Epoch 894/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7277
# Epoch 895/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7094
# Epoch 896/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6968
# Epoch 897/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.6666
# Epoch 898/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.7065
# Epoch 899/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6982
# Epoch 900/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6913
# Epoch 901/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6334
# Epoch 902/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6665
# Epoch 903/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6730
# Epoch 904/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.6785
# Epoch 905/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6676
# Epoch 906/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6424
# Epoch 907/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6505
# Epoch 908/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.6431
# Epoch 909/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 4.6711
# Epoch 910/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7103
# Epoch 911/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6211
# Epoch 912/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6594
# Epoch 913/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 4.6957
# Epoch 914/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6276
# Epoch 915/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.7331
# Epoch 916/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.6295
# Epoch 917/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6480
# Epoch 918/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6723
# Epoch 919/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 4.7066
# Epoch 920/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6966
# Epoch 921/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6618
# Epoch 922/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6713
# Epoch 923/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.7169
# Epoch 924/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6311
# Epoch 925/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6908
# Epoch 926/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6867
# Epoch 927/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6431
# Epoch 928/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6588
# Epoch 929/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.7139
# Epoch 930/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6764
# Epoch 931/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6997
# Epoch 932/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6738
# Epoch 933/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6346
# Epoch 934/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6539
# Epoch 935/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6954
# Epoch 936/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7221
# Epoch 937/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6443
# Epoch 938/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.7241
# Epoch 939/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6454
# Epoch 940/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.7022
# Epoch 941/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 4.6417
# Epoch 942/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6239
# Epoch 943/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 4.6015
# Epoch 944/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6500
# Epoch 945/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6418
# Epoch 946/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6952
# Epoch 947/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6361
# Epoch 948/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6637
# Epoch 949/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6518
# Epoch 950/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6615
# Epoch 951/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6593
# Epoch 952/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6656
# Epoch 953/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6461
# Epoch 954/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.7250
# Epoch 955/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7058
# Epoch 956/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.6457
# Epoch 957/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6446
# Epoch 958/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6577
# Epoch 959/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6654
# Epoch 960/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6864
# Epoch 961/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6017
# Epoch 962/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6528
# Epoch 963/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6581
# Epoch 964/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6391
# Epoch 965/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6625
# Epoch 966/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.6596
# Epoch 967/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6536
# Epoch 968/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6669
# Epoch 969/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6164
# Epoch 970/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 4.6380
# Epoch 971/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6495
# Epoch 972/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.7335
# Epoch 973/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6922
# Epoch 974/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6919
# Epoch 975/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6925
# Epoch 976/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.7020
# Epoch 977/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6279
# Epoch 978/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 4.6584
# Epoch 979/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.6554
# Epoch 980/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6758
# Epoch 981/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.6251
# Epoch 982/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6150
# Epoch 983/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.6491
# Epoch 984/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 4.6695
# Epoch 985/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6768
# Epoch 986/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6189
# Epoch 987/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6206
# Epoch 988/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.6426
# Epoch 989/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 4.6455
# Epoch 990/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6663
# Epoch 991/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 4.5842
# Epoch 992/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6380
# Epoch 993/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 4.6449
# Epoch 994/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 4.6291
# Epoch 995/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6662
# Epoch 996/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6121
# Epoch 997/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 4.6323
# Epoch 998/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 4.5534
# Epoch 999/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 4.6763
# Epoch 1000/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 4.6281

# %%
user_list_1=user_title_list[user_title_list.user>600]

# %%
user_list_1.head(10)
# Out:
#      user  ... predict_labels
# 601   601  ...             43
# 602   602  ...            921
# 603   603  ...            657
# 604   604  ...            481
# 605   605  ...           1181
# 606   606  ...            191
# 607   607  ...            134
# 608   608  ...            444
# 609   609  ...            428
# 610   610  ...            330
#
# [10 rows x 8 columns]

# %%
predict =model.predict([tf.keras.preprocessing.sequence.pad_sequences(user_list_1['title_d']),
          tf.keras.preprocessing.sequence.pad_sequences(user_list_1['like']),
          tf.keras.preprocessing.sequence.pad_sequences(user_list_1['dislike']),
          tf.keras.preprocessing.sequence.pad_sequences(user_list_1['all_genres'])
          ])

# %%
predictions = np.array([np.argmax(a) for a in predict])

# %%
user_list_1['predicted_label'] = predictions
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
user_list_1
# Out:
#      user  ... predicted_label
# 601   601  ...             305
# 602   602  ...             336
# 603   603  ...             303
# 604   604  ...             363
# 605   605  ...             253
# ..    ...  ...             ...
# 938   938  ...             250
# 939   939  ...             539
# 940   940  ...             276
# 941   941  ...             305
# 942   942  ...             305
#
# [342 rows x 9 columns]

# %%
print(tf.argsort(predict,direction='DESCENDING',axis=-1))
# Out:
# tf.Tensor(
# [[ 305  539    6 ...  193 1217  860]
#  [ 336  341  916 ... 1155 1532  402]
#  [ 303  305  539 ... 1214 1557 1001]
#  ...
#  [ 276  305 1171 ... 1121  773  696]
#  [ 305  250  478 ... 1554 1341   73]
#  [ 305  250  478 ... 1554 1341   73]], shape=(342, 1683), dtype=int32)

# %%
tf.nn.top_k(
    predict,
    k=20,
    sorted=True,
    name=None
)
# Out:
# TopKV2(values=<tf.Tensor: shape=(342, 20), dtype=float32, numpy=
# array([[0.0176613 , 0.01759837, 0.01540285, ..., 0.00830983, 0.00827789,
#         0.00800071],
#        [0.03552007, 0.03203171, 0.02963639, ..., 0.0119539 , 0.01190289,
#         0.01150583],
#        [0.01860192, 0.01733984, 0.0169874 , ..., 0.00753941, 0.00722815,
#         0.00717176],
#        ...,
#        [0.01267103, 0.00917798, 0.00838861, ..., 0.00643111, 0.0062839 ,
#         0.00608788],
#        [0.01257429, 0.01093409, 0.00912522, ..., 0.00574671, 0.00573995,
#         0.00572002],
#        [0.01257429, 0.01093409, 0.00912522, ..., 0.00574671, 0.00573995,
#         0.00572002]], dtype=float32)>, indices=<tf.Tensor: shape=(342, 20), dtype=int32, numpy=
# array([[ 305,  539,    6, ...,   48,  311,  290],
#        [ 336,  341,  916, ...,  127,  364,  904],
#        [ 303,  305,  539, ..., 1040,  715, 1013],
#        ...,
#        [ 276,  305, 1171, ...,  609, 1402,  453],
#        [ 305,  250,  478, ...,  309,  135,   84],
#        [ 305,  250,  478, ...,  309,  135,   84]], dtype=int32)>)

# %%
s=[i for i in range(len(movie2movie_encoded)) if movie2movie_encoded[i] == 365 ]

# %%
movies[movies.movie_id == ''.join(str(s[0]))]
# Out:
#     movie_id               title release_date  ...  Western  year  all_genres
# 368      368  Black Sheep (1996)  02-Feb-1996  ...        0  1996           5
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Visualize Embeddings

# %%
import io
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
#weights =model.layers[4].get_weights()[0]
weights = features_embedding_layer.get_weights()[0][1:]

for num, word in enumerate(title2title_encoded):
  vec = weights[num+1] # skip 0, it's padding.
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in vec]) + "\n")
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
except ImportError:
   pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')
